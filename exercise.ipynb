# %% [markdown]
# # Practice your skills loading data from a CSV file
# In this exercise, you will load a CSV file and you'll perform some operations on it to extract data. If you know how to do this with the Pandas library, you can use that. If not, you can use the csv library with the ready-to-use example this notebook provides.

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data/wine-ratings-small.csv")
df.head(20)
# Out:
#     Unnamed: 0                                      name  grape  \
# 0            0  Laurenz V Charming Gruner Veltliner 2013    NaN
# 1            1  Laurenz V Charming Gruner Veltliner 2014    NaN
# 2            2   Laurenz V Singing Gruner Veltliner 2007    NaN
# 3            3   Laurenz V Singing Gruner Veltliner 2010    NaN
# 4            4   Laurenz V Singing Gruner Veltliner 2011    NaN
# 5            5   Laurenz V Singing Gruner Veltliner 2013    NaN
# 6            6               Lava Cap American River Red    NaN
# 7            7                     Lava Cap Barbera 2010    NaN
# 8            8        Lava Cap Battonage Chardonnay 2012    NaN
# 9            9          Lava Cap Cabernet Sauvignon 2013    NaN
# 10          10          Lava Cap Cabernet Sauvignon 2016    NaN
# 11          11                Lava Cap Petite Sirah 2013    NaN
# 12          12                Lava Cap Petite Sirah 2014    NaN
# 13          13                Lava Cap Petite Sirah 2016    NaN
# 14          14          Lava Cap Reserve Chardonnay 2015    NaN
# 15          15          Lava Cap Reserve Chardonnay 2018    NaN
# 16          16          Lava Cap Reserve Chardonnay 2016    NaN
# 17          17              Lava Cap Reserve Merlot 2015    NaN
# 18          18             Lava Cap Sauvignon Blanc 2015    NaN
# 19          19             Lava Cap Sauvignon Blanc 2017    NaN
#
#                                      region     variety  rating  \
# 0                          Kamptal, Austria  White Wine    90.0
# 1                          Kamptal, Austria  White Wine    90.0
# 2                                   Austria  White Wine    90.0
# 3                                   Austria  White Wine    88.0
# 4                                   Austria  White Wine    88.0
# 5                                   Austria  White Wine    89.0
# 6   El Dorado, Sierra Foothills, California    Red Wine    90.0
# 7              Sierra Foothills, California    Red Wine    90.0
# 8              Sierra Foothills, California  White Wine    91.0
# 9   El Dorado, Sierra Foothills, California    Red Wine    90.0
# 10  El Dorado, Sierra Foothills, California    Red Wine    93.0
# 11  El Dorado, Sierra Foothills, California    Red Wine    90.0
# 12  El Dorado, Sierra Foothills, California    Red Wine    92.0
# 13  El Dorado, Sierra Foothills, California    Red Wine    92.0
# 14  El Dorado, Sierra Foothills, California  White Wine    92.0
# 15  El Dorado, Sierra Foothills, California  White Wine    92.0
# 16  El Dorado, Sierra Foothills, California  White Wine    92.0
# 17  El Dorado, Sierra Foothills, California    Red Wine    90.0
# 18  El Dorado, Sierra Foothills, California  White Wine    90.0
# 19  El Dorado, Sierra Foothills, California  White Wine    89.0
#
#                                                 notes
# 0   Aromas of ripe apples and a typical Veltliner ...
# 1   Aromas of ripe apples and a typical Veltliner ...
# 2   A very attractive fruit bouquet yields apple, ...
# 3   A very attractive fruit bouquet yields apple, ...
# 4   A very attractive fruit bouquet yields apple, ...
# 5   A very attractive fruit bouquet yields apple, ...
# 6   This wine was created as a table wine. We want...
# 7   The plump, rich cherry, raspberry and plum fru...
# 8   This perfectly balanced wine begins with invit...
# 9   Lava Cap’s estate grown Cabernet Sauvignon gra...
# 10  Lava Cap’s estate grown grapes have long been ...
# 11  Lava Cap's 2013 Petite Sirah is a BIG one for ...
# 12  On the nose, the 2014 Petite Sirah has notes o...
# 13  The 2016 Petite Sirah has notes of elegant wil...
# 14  Zesty lemon and apple blossom aroma lead into ...
# 15  The 2018 vintage continues to consistently ele...
# 16  Zesty lemon and apple blossom aroma lead into ...
# 17  Pleasant forest greenery and plum scents highl...
# 18  An expressive aromatic wine displays note soft...
# 19  After the grapes are crushed, they are 100% fe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  780 non-null    int64
#  1   name        780 non-null    object
#  2   grape       0 non-null      float64
#  3   region      780 non-null    object
#  4   variety     777 non-null    object
#  5   rating      780 non-null    float64
#  6   notes       775 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 42.8+ KB

# %%
wines_type = df['variety']
wines_type.head()
# Out:
# 0    White Wine
# 1    White Wine
# 2    White Wine
# 3    White Wine
# 4    White Wine
# Name: variety, dtype: object

# %%
wines_type.unique()
# Out:
# array(['White Wine', 'Red Wine', 'Sparkling & Champagne', 'Pink and Rosé',
#        nan, 'Collectible'], dtype=object)

# %%
wines_type.nunique()
# Out:
# 5

# %%
df['grapes'] = df['grape'].fillna(0).round(2)
df.head()
# Out:
#    Unnamed: 0                                      name  grape  \
# 0           0  Laurenz V Charming Gruner Veltliner 2013    NaN
# 1           1  Laurenz V Charming Gruner Veltliner 2014    NaN
# 2           2   Laurenz V Singing Gruner Veltliner 2007    NaN
# 3           3   Laurenz V Singing Gruner Veltliner 2010    NaN
# 4           4   Laurenz V Singing Gruner Veltliner 2011    NaN
#
#              region     variety  rating  \
# 0  Kamptal, Austria  White Wine    90.0
# 1  Kamptal, Austria  White Wine    90.0
# 2           Austria  White Wine    90.0
# 3           Austria  White Wine    88.0
# 4           Austria  White Wine    88.0
#
#                                                notes  grapes
# 0  Aromas of ripe apples and a typical Veltliner ...     0.0
# 1  Aromas of ripe apples and a typical Veltliner ...     0.0
# 2  A very attractive fruit bouquet yields apple, ...     0.0
# 3  A very attractive fruit bouquet yields apple, ...     0.0
# 4  A very attractive fruit bouquet yields apple, ...     0.0

# %%
df.drop(['grape'], axis=1)
# Out:
#      Unnamed: 0                                          name  \
# 0             0      Laurenz V Charming Gruner Veltliner 2013
# 1             1      Laurenz V Charming Gruner Veltliner 2014
# 2             2       Laurenz V Singing Gruner Veltliner 2007
# 3             3       Laurenz V Singing Gruner Veltliner 2010
# 4             4       Laurenz V Singing Gruner Veltliner 2011
# ..          ...                                           ...
# 775         775        Lewis Cellars Syrah Ethan's Blend 2005
# 776         776        Lewis Cellars Syrah Ethan's Blend 2014
# 777         777        Lewis Cellars Syrah Ethan's Blend 2009
# 778         778                       Lexington Apex Red 2011
# 779         779  Lexington Gist Ranch Cabernet Sauvignon 2011
#
#                                region     variety  rating  \
# 0                    Kamptal, Austria  White Wine    90.0
# 1                    Kamptal, Austria  White Wine    90.0
# 2                             Austria  White Wine    90.0
# 3                             Austria  White Wine    88.0
# 4                             Austria  White Wine    88.0
# ..                                ...         ...     ...
# 775                        California    Red Wine    92.0
# 776                        California    Red Wine    93.0
# 777                        California    Red Wine    94.0
# 778  Santa Cruz Mountains, California    Red Wine    91.0
# 779  Santa Cruz Mountains, California    Red Wine    91.0
#
#                                                  notes  grapes
# 0    Aromas of ripe apples and a typical Veltliner ...     0.0
# 1    Aromas of ripe apples and a typical Veltliner ...     0.0
# 2    A very attractive fruit bouquet yields apple, ...     0.0
# 3    A very attractive fruit bouquet yields apple, ...     0.0
# 4    A very attractive fruit bouquet yields apple, ...     0.0
# ..                                                 ...     ...
# 775  Now 7 years old, Alec's younger brother Ethan ...     0.0
# 776  Born in 2000, everything about Ethan and his n...     0.0
# 777  Positioned between brothers, Alec and Mason, E...     0.0
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot      0.0
# 779          Blend: 80% Cabernet Sauvignon, 20% Merlot     0.0
#
# [780 rows x 7 columns]

# %%
region = df['region']
region.head()
# Out:
# 0    Kamptal, Austria
# 1    Kamptal, Austria
# 2             Austria
# 3             Austria
# 4             Austria
# Name: region, dtype: object

# %%
region.unique()
# Out:
# array(['Kamptal, Austria', 'Austria',
#        'El Dorado, Sierra Foothills, California',
#        'Sierra Foothills, California', 'California',
#        'Knights Valley, Sonoma County, California',
#        'Napa Valley, California', 'Chateauneuf-du-Pape, Rhone, France',
#        'Gigondas, Rhone, France', 'Rasteau, Rhone, France',
#        'Paso Robles, Central Coast, California',
#        'Central Coast, California',
#        'Willow Creek District, Paso Robles, Central Coast, California',
#        'Eola-Amity Hills, Willamette Valley, Oregon',
#        'Yamhill-Carlton District, Willamette Valley, Oregon',
#        'Dundee Hills, Willamette Valley, Oregon',
#        'Willamette Valley, Oregon', 'Portugal', 'New Zealand',
#        'Marlborough, New Zealand', 'Spain', 'Argentina', 'Italy',
#        'South Australia, Australia', 'Tuscany, Italy', 'South Africa',
#        'Champagne, France', 'St. Emilion, Bordeaux, France',
#        'Sicily, Italy', 'Rhone, France', 'Montalcino, Tuscany, Italy',
#        'France', 'Cahors, Southwest, France', 'Prosecco, Italy',
#        'Valdobbiadene, Prosecco, Italy',
#        'Chianti Classico, Chianti, Tuscany, Italy',
#        'Chablis, Burgundy, France', 'Friuli-Venezia Giulia, Italy',
#        'Bolgheri, Tuscany, Italy', 'Monterey, Central Coast, California',
#        'San Benito, Central Coast, California',
#        'Valpolicella, Veneto, Italy', 'Sancerre, Loire, France',
#        'Veneto, Italy', 'Marche, Italy',
#        'Sta. Rita Hills, Santa Barbara, Central Coast, California',
#        'Madeira, Portugal', 'Australia',
#        'Clare Valley, South Australia, Australia',
#        "Gevrey-Chambertin, Cote de Nuits, Cote d'Or, Burgundy, France",
#        "Morey-St-Denis, Cote de Nuits, Cote d'Or, Burgundy, France",
#        "Nuits-St-Georges, Cote de Nuits, Cote d'Or, Burgundy, France",
#        'Burgundy, France', 'Columbia Valley, Washington',
#        'Walla Walla Valley, Columbia Valley, Washington', 'Washington',
#        'Margaret River, Western Australia, Australia',
#        'Alexander Valley, Sonoma County, California',
#        'Ribera del Duero, Spain', 'Oregon',
#        'McLaren Vale, South Australia, Australia',
#        'Santa Cruz Mountains, California',
#        'Santa Ynez Valley, Santa Barbara, Central Coast, California',
#        'Mendocino, California',
#        'Dry Creek Valley, Sonoma County, California',
#        'Sonoma Mountain, Sonoma Valley, Sonoma County, California',
#        'Puglia, Italy', 'Cornas, Rhone, France',
#        'Crozes-Hermitage, Rhone, France', 'Saint-Joseph, Rhone, France',
#        'Vin de France, France', 'Cotes du Rhone, Rhone, France',
#        "Valle d'Aosta, Italy", 'Pauillac, Bordeaux, France',
#        'Bordeaux, France',
#        "Coteaux d'Aix-en-Provence, Provence, South of France, France",
#        'Cotes du Roussillon-Tautavel, Côtes du Roussillon-Villages, Roussillon, South of France, France',
#        'Provence, South of France, France',
#        'Terrasses du Larzac, Languedoc, South of France, France',
#        'Pessac-Leognan, Bordeaux, France',
#        'Russian River, Sonoma County, California',
#        'Cote Rotie, Rhone, France', 'North Coast, California',
#        'St. Helena, Napa Valley, California',
#        'Rutherford, Napa Valley, California', 'Sonoma County, California'],
#       dtype=object)

# %%
region.nunique()
# Out:
# 86

# %%
rate = df['rating']
rate.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 780 entries, 0 to 779
# Series name: rating
# Non-Null Count  Dtype
# --------------  -----
# 780 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
rate.describe().round(2)
# Out:
# count    780.00
# mean      91.42
# std        1.93
# min       85.00
# 25%       90.00
# 50%       91.00
# 75%       93.00
# max       99.00
# Name: rating, dtype: float64

# %%
rating_betn = df.loc[(df['rating'] > 89) & (df['rating'] < 93), ['rating','name']]

# %%
print(rating_betn)
# Out:
#      rating                                          name
# 0      90.0      Laurenz V Charming Gruner Veltliner 2013
# 1      90.0      Laurenz V Charming Gruner Veltliner 2014
# 2      90.0       Laurenz V Singing Gruner Veltliner 2007
# 6      90.0                   Lava Cap American River Red
# 7      90.0                         Lava Cap Barbera 2010
# ..      ...                                           ...
# 773    92.0          Lewis Cellars Sonoma Chardonnay 2017
# 774    91.0   Lewis Cellars Sonoma Valley Chardonnay 2008
# 775    92.0        Lewis Cellars Syrah Ethan's Blend 2005
# 778    91.0                       Lexington Apex Red 2011
# 779    91.0  Lexington Gist Ranch Cabernet Sauvignon 2011
#
# [514 rows x 2 columns]

# %%
rating_betn.count()
# Out:
# rating    514
# name      514
# dtype: int64

# %%
df.drop(['grape'], axis=1, inplace=True)

# %%
df = df.where(pd.notnull(df), None)

# %%
df
# Out:
#      Unnamed: 0                                          name  \
# 0             0      Laurenz V Charming Gruner Veltliner 2013
# 1             1      Laurenz V Charming Gruner Veltliner 2014
# 2             2       Laurenz V Singing Gruner Veltliner 2007
# 3             3       Laurenz V Singing Gruner Veltliner 2010
# 4             4       Laurenz V Singing Gruner Veltliner 2011
# ..          ...                                           ...
# 775         775        Lewis Cellars Syrah Ethan's Blend 2005
# 776         776        Lewis Cellars Syrah Ethan's Blend 2014
# 777         777        Lewis Cellars Syrah Ethan's Blend 2009
# 778         778                       Lexington Apex Red 2011
# 779         779  Lexington Gist Ranch Cabernet Sauvignon 2011
#
#                                region     variety  rating  \
# 0                    Kamptal, Austria  White Wine    90.0
# 1                    Kamptal, Austria  White Wine    90.0
# 2                             Austria  White Wine    90.0
# 3                             Austria  White Wine    88.0
# 4                             Austria  White Wine    88.0
# ..                                ...         ...     ...
# 775                        California    Red Wine    92.0
# 776                        California    Red Wine    93.0
# 777                        California    Red Wine    94.0
# 778  Santa Cruz Mountains, California    Red Wine    91.0
# 779  Santa Cruz Mountains, California    Red Wine    91.0
#
#                                                  notes  grapes
# 0    Aromas of ripe apples and a typical Veltliner ...     0.0
# 1    Aromas of ripe apples and a typical Veltliner ...     0.0
# 2    A very attractive fruit bouquet yields apple, ...     0.0
# 3    A very attractive fruit bouquet yields apple, ...     0.0
# 4    A very attractive fruit bouquet yields apple, ...     0.0
# ..                                                 ...     ...
# 775  Now 7 years old, Alec's younger brother Ethan ...     0.0
# 776  Born in 2000, everything about Ethan and his n...     0.0
# 777  Positioned between brothers, Alec and Mason, E...     0.0
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot      0.0
# 779          Blend: 80% Cabernet Sauvignon, 20% Merlot     0.0
#
# [780 rows x 7 columns]

# %%
import json

with open("wine_data.json", "w") as f:
    json.dump(df.to_dict(orient="records"), f)
